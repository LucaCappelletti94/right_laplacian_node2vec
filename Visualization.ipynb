# %%
import pandas as pd
from barplots import barplots

# %%
df = pd.read_csv("right_laplacian_experiments.csv", sep=",")

# %%
df
# Out:
#          loss  accuracy    recall  precision     AUROC     AUPRC  f1_score  \
# 0    0.683237  0.599609  0.947266   0.558756  0.738768  0.705575  0.702899
# 1    0.623684  0.633789  0.847656   0.593707  0.771246  0.783812  0.698311
# 2    0.877279  0.568359  0.947266   0.538889  0.544285  0.534798  0.686969
# 3    0.652541  0.573242  0.847656   0.547289  0.751614  0.793998  0.665134
# 4    0.929098  0.474609  0.947266   0.486948  0.456079  0.579663  0.643236
# ..        ...       ...       ...        ...       ...       ...       ...
# 115  0.456667  0.763672  0.974609   0.685440  0.941055  0.941806  0.804839
# 116  0.708486  0.658203  0.962891   0.598301  0.697792  0.578525  0.738024
# 117  0.680725  0.621094  0.974609   0.570938  0.797499  0.786970  0.720058
# 118  0.645685  0.633789  0.962891   0.580683  0.776867  0.777691  0.724467
# 119  0.455208  0.755859  0.974609   0.677989  0.949484  0.954810  0.799679
#
#      balanced_accuracy  specificity  miss_rate  fall_out       mcc  \
# 0             0.599609     0.251953   0.052734  0.748047  0.277190
# 1             0.633789     0.419922   0.152344  0.580078  0.296025
# 2             0.568359     0.189453   0.052734  0.810547  0.209540
# 3             0.573242     0.298828   0.152344  0.701172  0.175234
# 4             0.474609     0.001953   0.052734  0.998047 -0.155691
# ..                 ...          ...        ...       ...       ...
# 115           0.763672     0.552734   0.025391  0.447266  0.581637
# 116           0.658203     0.353516   0.037109  0.646484  0.399058
# 117           0.621094     0.267578   0.025391  0.732422  0.342468
# 118           0.633789     0.304688   0.037109  0.695312  0.355425
# 119           0.755859     0.537109   0.025391  0.462891  0.569071
#
#     evaluation_type  unbalance   graph_name normalization_name
# 0             train        1.0  HomoSapiens        Traditional
# 1              test        1.0  HomoSapiens        Traditional
# 2             train       10.0  HomoSapiens        Traditional
# 3              test       10.0  HomoSapiens        Traditional
# 4             train      100.0  HomoSapiens        Traditional
# ..              ...        ...          ...                ...
# 115            test        1.0  HomoSapiens    Right Laplacian
# 116           train       10.0  HomoSapiens    Right Laplacian
# 117            test       10.0  HomoSapiens    Right Laplacian
# 118           train      100.0  HomoSapiens    Right Laplacian
# 119            test      100.0  HomoSapiens    Right Laplacian
#
# [120 rows x 16 columns]

# %%
barplots(
    df,
    groupby=["evaluation_type", "normalization_name", "unbalance"]
)
# Out:
# Rendering barplots:   0%|                                                                              | 0/12 …
# ((<Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>),
#  (array([<AxesSubplot:title={'center':'Miss rate'}, ylabel='Miss rate'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'AUROC'}, ylabel='AUROC'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Balanced Accuracy'}, ylabel='Balanced Accuracy'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Recall'}, ylabel='Recall'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Loss'}, ylabel='Loss'>], dtype=object),
#   array([<AxesSubplot:title={'center':'Matthews correlation coefficient'}, ylabel='Matthews correlation coefficient'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Fall out'}, ylabel='Fall out'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Precision'}, ylabel='Precision'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Specificity'}, ylabel='Specificity'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'AUPRC'}, ylabel='AUPRC'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'F1 Score'}, ylabel='F1 Score'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Accuracy'}, ylabel='Accuracy'>],
#         dtype=object)))
