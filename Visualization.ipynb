# %%
import pandas as pd
from barplots import barplots
from tabulate import tabulate

# %%
df = pd.read_csv("right_laplacian_experiments.csv", sep=",")

# %%
df[df.columns[-7:]].sample(10)[:10]
# Out:
#       miss_rate  fall_out       mcc evaluation_type unbalance  \
# 909    0.011719  0.785156  0.320451            test      10.0
# 1144   0.248047  0.103516  0.655318           train     100.0
# 217    0.003906  0.689453  0.421193            test       1.0
# 584    0.167969  0.863281 -0.043481           train      10.0
# 459    0.111328  0.679688  0.253998            test      10.0
# 360    0.267578  0.908203 -0.228925           train       1.0
# 208    0.009766  0.994141 -0.022184           train     100.0
# 609    0.035156  0.632812  0.414132            test      10.0
# 224    0.000000  0.990234  0.070048           train      10.0
# 1011   0.037109  0.619141  0.422730            test      10.0
#
#                      graph_name normalization_name
# 909                 MusMusculus    Right Laplacian
# 1144                 CanisLupus    Right Laplacian
# 217     SaccharomycesCerevisiae        Traditional
# 584                  CanisLupus        Traditional
# ...

# %%
barplots(
    df,
    subplots=True,
    groupby=["evaluation_type", "normalization_name", "unbalance", "graph_name"],
)
# Out:
# Rendering barplots:   0%|                                                                              | 0/12 …
# ((<Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>,
#   <Figure size 6480x2002.43 with 2 Axes>),
#  (array([<AxesSubplot:title={'center':'Test'}, ylabel='F1 Score'>,
#          <AxesSubplot:title={'center':'Train'}>], dtype=object),
#   array([<AxesSubplot:title={'center':'Test'}, ylabel='AUPRC'>,
#          <AxesSubplot:title={'center':'Train'}>], dtype=object),
# ...
