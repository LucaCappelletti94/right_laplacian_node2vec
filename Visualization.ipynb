# %%
import pandas as pd
from barplots import barplots

# %%
df = pd.read_csv("right_laplacian_experiments.csv", sep=",")
df.unbalance = df.unbalance.astype(str)

# %%
df
# Out:
#         loss  accuracy    recall  precision     AUROC     AUPRC  f1_score  \
# 0   0.678058  0.604492  0.900391   0.565644  0.758926  0.766165  0.694800
# 1   0.646600  0.619141  0.839844   0.582656  0.758390  0.787642  0.688000
# 2   0.903975  0.519531  0.900391   0.511086  0.600605  0.632428  0.652051
# 3   0.825185  0.518555  0.839844   0.511296  0.644482  0.680874  0.635625
# 4   0.618978  0.560547  0.900391   0.536047  0.797924  0.859666  0.672012
# 5   0.778309  0.460938  0.839844   0.477778  0.676647  0.749614  0.609065
# 6   0.676092  0.634766  0.929688   0.584767  0.729696  0.697935  0.717949
# 7   0.661474  0.594727  0.847656   0.562905  0.729790  0.746577  0.676539
# 8   0.777334  0.547852  0.929688   0.527132  0.652664  0.645168  0.672792
# 9   0.643329  0.658203  0.847656   0.614731  0.747908  0.721707  0.712644
# 10  0.701973  0.511719  0.929688   0.506383  0.697107  0.773793  0.655647
# 11  0.714625  0.529297  0.847656   0.517900  0.685514  0.737782  0.642963
# ...

# %%
barplots(
    df,
    groupby=["evaluation_type", "normalization_name", "unbalance"]
)
# Out:
# Rendering barplots:   0%|                                                                              | 0/12 …
# ((<Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>,
#   <Figure size 960x593.313 with 1 Axes>),
#  (array([<AxesSubplot:title={'center':'Loss'}, ylabel='Loss'>], dtype=object),
#   array([<AxesSubplot:title={'center':'Matthews correlation coefficient'}, ylabel='Matthews correlation coefficient'>],
#         dtype=object),
#   array([<AxesSubplot:title={'center':'Miss rate'}, ylabel='Miss rate'>],
#         dtype=object),
# ...
